# %%
# !pip install muax==0.0.2.7.1a0
# Out:
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# Requirement already satisfied: muax==0.0.2.7.1a0 in /opt/conda/lib/python3.7/site-packages (0.0.2.7.1a0)
# Requirement already satisfied: optax in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1a0) (0.1.4)
# Requirement already satisfied: mctx in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1a0) (0.0.2)
# Requirement already satisfied: gymnasium in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1a0) (0.27.1)
# Requirement already satisfied: lz4 in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1a0) (4.0.2)
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1a0) (2.5.1)
# Requirement already satisfied: dm-haiku in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1a0) (0.0.9)
# Requirement already satisfied: absl-py>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1a0) (1.3.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1a0) (4.4.0)
# Requirement already satisfied: jmp>=0.0.2 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1a0) (0.0.4)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1a0) (0.9.0)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1a0) (1.21.6)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1a0) (5.1.0)
# Requirement already satisfied: jax-jumpy>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1a0) (0.2.0)
# Requirement already satisfied: gymnasium-notices>=0.0.1 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1a0) (0.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1a0) (2.2.0)
# Requirement already satisfied: jax>=0.1.55 in /opt/conda/lib/python3.7/site-packages (from mctx->muax==0.0.2.7.1a0) (0.3.25)
# Requirement already satisfied: jaxlib>=0.1.37 in /opt/conda/lib/python3.7/site-packages (from mctx->muax==0.0.2.7.1a0) (0.3.25+cuda11.cudnn82)
# Requirement already satisfied: chex>=0.0.8 in /opt/conda/lib/python3.7/site-packages (from mctx->muax==0.0.2.7.1a0) (0.1.5)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /opt/conda/lib/python3.7/site-packages (from tensorboardX->muax==0.0.2.7.1a0) (3.19.6)
# Requirement already satisfied: toolz>=0.9.0 in /opt/conda/lib/python3.7/site-packages (from chex>=0.0.8->mctx->muax==0.0.2.7.1a0) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /opt/conda/lib/python3.7/site-packages (from chex>=0.0.8->mctx->muax==0.0.2.7.1a0) (0.1.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=4.8.0->gymnasium->muax==0.0.2.7.1a0) (3.11.0)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.7/site-packages (from jax>=0.1.55->mctx->muax==0.0.2.7.1a0) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.7/site-packages (from jax>=0.1.55->mctx->muax==0.0.2.7.1a0) (1.7.3)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)

# %%
import jax 
from jax import numpy as jnp
jax.config.update('jax_platform_name', 'cpu')

import muax
from muax import nn

# %%
import haiku as hk

class Representation(hk.Module):
  def __init__(self, embedding_dim, name='representation'):
    super().__init__(name=name)

    self.repr_func = hk.Sequential([
        hk.Linear(embedding_dim)
    ])

  def __call__(self, obs):
    s = self.repr_func(obs)
    return s 


class Prediction(hk.Module):
  def __init__(self, num_actions, full_support_size, name='prediction'):
    super().__init__(name=name)        
    
    self.v_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.pi_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(num_actions)
    ])
  
  def __call__(self, s):
    v = self.v_func(s)
    logits = self.pi_func(s)
    logits = jax.nn.softmax(logits, axis=-1)
    return v, logits


class Dynamic(hk.Module):
  def __init__(self, embedding_dim, num_actions, full_support_size, name='dynamic'):
    super().__init__(name=name)
    
    self.ns_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(embedding_dim)
    ])
    self.r_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.cat_func = jax.jit(lambda s, a: 
                            jnp.concatenate([s, jax.nn.one_hot(a, num_actions)],
                                            axis=1)
                            )
  
  def __call__(self, s, a):
    sa = self.cat_func(s, a)
    r = self.r_func(sa)
    ns = self.ns_func(sa)
    return r, ns


def init_representation_func(representation_module, embedding_dim):
    def representation_func(obs):
      repr_model = representation_module(embedding_dim)
      return repr_model(obs)
    return representation_func
  
def init_prediction_func(prediction_module, num_actions, full_support_size):
  def prediction_func(s):
    pred_model = prediction_module(num_actions, full_support_size)
    return pred_model(s)
  return prediction_func

def init_dynamic_func(dynamic_module, embedding_dim, num_actions, full_support_size):
  def dynamic_func(s, a):
    dy_model = dynamic_module(embedding_dim, num_actions, full_support_size)
    return dy_model(s, a)
  return dynamic_func

# %%
support_size = 10 
embedding_size = 10
discount = 0.999
num_actions = 4
full_support_size = int(support_size * 2 + 1)

repr_fn = init_representation_func(Representation, embedding_size)
pred_fn = init_prediction_func(Prediction, num_actions, full_support_size)
dy_fn = init_dynamic_func(Dynamic, embedding_size, num_actions, full_support_size)

tracer = muax.PNStep(50, discount, 0.5)
buffer = muax.TrajectoryReplayBuffer(500)

gradient_transform = muax.model.optimizer(init_value=0.005, peak_value=0.005, end_value=0.005, warmup_steps=20000, transition_steps=20000)

# %%
model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=discount,
                    optimizer=gradient_transform, support_size=support_size)

model_path = muax.fit(model, 'LunarLander-v2', 
                    max_episodes=1000,
                    max_training_steps=40000,
                    tracer=tracer,
                    buffer=buffer,
                    k_steps=10,
                    sample_per_trajectory=1,
                    num_trajectory=32,
                    tensorboard_dir='/home/fangbowen/tensorboard/LunarLander',
                    model_save_path='/home/fangbowen/models/LunarLander',
                    save_name='lunarlander_model_params',
                    random_seed=0,
                    log_all_metrics=True)
# Out:
# buffer warm up stage...
# start training...
# INFO:TrainMonitor:ep: 1,	T: 59,	G: -20.6,	avg_r: -0.354,	avg_G: -20.6,	t: 58,	dt: 177.084ms,	v: -2.25,	Rn: 2.98,	loss: 3.95,	training_step: 57,	test_G: -861
# INFO:TrainMonitor:ep: 2,	T: 123,	G: -140,	avg_r: -2.22,	avg_G: -80.1,	t: 63,	dt: 24.169ms,	v: -86.7,	Rn: -107,	loss: 3.67,	training_step: 119
# INFO:TrainMonitor:ep: 3,	T: 197,	G: -187,	avg_r: -2.57,	avg_G: -116,	t: 73,	dt: 23.888ms,	v: -97.3,	Rn: -146,	loss: 3.61,	training_step: 191
# INFO:TrainMonitor:ep: 4,	T: 254,	G: -197,	avg_r: -3.52,	avg_G: -136,	t: 56,	dt: 25.107ms,	v: -56.1,	Rn: -152,	loss: 3.62,	training_step: 246
# INFO:TrainMonitor:ep: 5,	T: 316,	G: -114,	avg_r: -1.87,	avg_G: -132,	t: 61,	dt: 24.207ms,	v: -67,	Rn: -102,	loss: 3.48,	training_step: 306
# INFO:TrainMonitor:ep: 6,	T: 377,	G: -112,	avg_r: -1.87,	avg_G: -128,	t: 60,	dt: 24.053ms,	v: -100,	Rn: -86.6,	loss: 3.45,	training_step: 365
# INFO:TrainMonitor:ep: 7,	T: 434,	G: -78.2,	avg_r: -1.4,	avg_G: -121,	t: 56,	dt: 24.292ms,	v: -90.1,	Rn: -69.5,	loss: 3.4,	training_step: 420
# INFO:TrainMonitor:ep: 8,	T: 496,	G: -101,	avg_r: -1.66,	avg_G: -119,	t: 61,	dt: 23.807ms,	v: -60.9,	Rn: -89,	loss: 3.43,	training_step: 480
# INFO:TrainMonitor:ep: 9,	T: 556,	G: -138,	avg_r: -2.34,	avg_G: -121,	t: 59,	dt: 23.725ms,	v: -61.1,	Rn: -116,	loss: 3.38,	training_step: 538
# INFO:TrainMonitor:ep: 10,	T: 655,	G: -292,	avg_r: -2.98,	avg_G: -138,	t: 98,	dt: 23.735ms,	v: -60.3,	Rn: -177,	loss: 3.39,	training_step: 635
# INFO:TrainMonitor:ep: 11,	T: 735,	G: -28.1,	avg_r: -0.356,	avg_G: -127,	t: 79,	dt: 40.611ms,	v: -72.5,	Rn: -49.1,	loss: 3.36,	training_step: 713,	test_G: -288
# INFO:TrainMonitor:ep: 12,	T: 792,	G: -88.4,	avg_r: -1.58,	avg_G: -123,	t: 56,	dt: 23.894ms,	v: -82.8,	Rn: -80.6,	loss: 3.39,	training_step: 768
# INFO:TrainMonitor:ep: 13,	T: 849,	G: -58.2,	avg_r: -1.04,	avg_G: -117,	t: 56,	dt: 23.640ms,	v: -78.1,	Rn: -58.9,	loss: 3.4,	training_step: 823
# INFO:TrainMonitor:ep: 14,	T: 909,	G: -65.1,	avg_r: -1.1,	avg_G: -112,	t: 59,	dt: 23.966ms,	v: -70.7,	Rn: -65.8,	loss: 3.3,	training_step: 881
# INFO:TrainMonitor:ep: 15,	T: 971,	G: -44.9,	avg_r: -0.737,	avg_G: -105,	t: 61,	dt: 24.213ms,	v: -75.7,	Rn: -52.3,	loss: 3.35,	training_step: 941
# INFO:TrainMonitor:ep: 16,	T: 1,032,	G: -75.6,	avg_r: -1.26,	avg_G: -102,	t: 60,	dt: 24.151ms,	v: -67.6,	Rn: -73.6,	loss: 3.36,	training_step: 1e+03
# INFO:TrainMonitor:ep: 17,	T: 1,102,	G: -74.4,	avg_r: -1.08,	avg_G: -99.2,	t: 69,	dt: 47.658ms,	v: -72.4,	Rn: -82.6,	loss: 3.27,	training_step: 1.07e+03
# INFO:TrainMonitor:ep: 18,	T: 1,177,	G: -57.9,	avg_r: -0.783,	avg_G: -95.1,	t: 74,	dt: 26.936ms,	v: -65.8,	Rn: -69.9,	loss: 3.29,	training_step: 1.14e+03
# INFO:TrainMonitor:ep: 19,	T: 1,243,	G: -52.1,	avg_r: -0.802,	avg_G: -90.8,	t: 65,	dt: 23.861ms,	v: -71.7,	Rn: -63.5,	loss: 3.29,	training_step: 1.20e+03
# INFO:TrainMonitor:ep: 20,	T: 1,310,	G: -35.5,	avg_r: -0.539,	avg_G: -85.3,	t: 66,	dt: 23.968ms,	v: -75.2,	Rn: -52.2,	loss: 3.28,	training_step: 1.27e+03
# INFO:TrainMonitor:ep: 21,	T: 1,388,	G: -29.4,	avg_r: -0.382,	avg_G: -79.7,	t: 77,	dt: 42.076ms,	v: -73.9,	Rn: -53.2,	loss: 3.29,	training_step: 1.35e+03,	test_G: -316
# INFO:TrainMonitor:ep: 22,	T: 1,468,	G: -27.4,	avg_r: -0.347,	avg_G: -74.4,	t: 79,	dt: 24.239ms,	v: -70,	Rn: -53.1,	loss: 3.28,	training_step: 1.42e+03
# INFO:TrainMonitor:ep: 23,	T: 1,549,	G: -27.4,	avg_r: -0.342,	avg_G: -69.7,	t: 80,	dt: 23.736ms,	v: -64.8,	Rn: -52.5,	loss: 3.29,	training_step: 1.5e+03
# INFO:TrainMonitor:ep: 24,	T: 1,627,	G: -32.3,	avg_r: -0.419,	avg_G: -66,	t: 77,	dt: 23.574ms,	v: -65.2,	Rn: -55.5,	loss: 3.3,	training_step: 1.58e+03
# INFO:TrainMonitor:ep: 25,	T: 1,712,	G: -29.2,	avg_r: -0.348,	avg_G: -62.3,	t: 84,	dt: 23.797ms,	v: -68,	Rn: -56,	loss: 3.31,	training_step: 1.66e+03
# INFO:TrainMonitor:ep: 26,	T: 1,817,	G: -16.8,	avg_r: -0.161,	avg_G: -57.8,	t: 104,	dt: 23.833ms,	v: -61.2,	Rn: -48.4,	loss: 3.25,	training_step: 1.76e+03
# INFO:TrainMonitor:ep: 27,	T: 2,818,	G: 52,	avg_r: 0.052,	avg_G: -46.8,	t: 1000,	dt: 26.112ms,	v: -66.8,	Rn: -10.3,	loss: 3.26,	training_step: 2.76e+03
# INFO:TrainMonitor:ep: 28,	T: 3,819,	G: -8.36,	avg_r: -0.00836,	avg_G: -42.9,	t: 1000,	dt: 29.403ms,	v: -64.5,	Rn: -10.9,	loss: 3.22,	training_step: 3.76e+03
# INFO:TrainMonitor:ep: 29,	T: 4,182,	G: -6.84,	avg_r: -0.0189,	avg_G: -39.3,	t: 362,	dt: 27.848ms,	v: -59.3,	Rn: -53.5,	loss: 3.23,	training_step: 4.12e+03
# INFO:TrainMonitor:ep: 30,	T: 5,183,	G: 12.5,	avg_r: 0.0125,	avg_G: -34.1,	t: 1000,	dt: 28.263ms,	v: -55.6,	Rn: -2.12,	loss: 3.2,	training_step: 5.12e+03
# INFO:TrainMonitor:ep: 31,	T: 6,184,	G: -106,	avg_r: -0.106,	avg_G: -41.3,	t: 1000,	dt: 39.828ms,	v: -46,	Rn: 0.584,	loss: 3.21,	training_step: 6.12e+03,	test_G: -232
# INFO:TrainMonitor:ep: 32,	T: 7,185,	G: -117,	avg_r: -0.117,	avg_G: -48.9,	t: 1000,	dt: 32.231ms,	v: -50,	Rn: -3.58,	loss: 3.2,	training_step: 7.12e+03
# INFO:TrainMonitor:ep: 33,	T: 7,529,	G: -435,	avg_r: -1.27,	avg_G: -87.5,	t: 343,	dt: 29.054ms,	v: -50.7,	Rn: -107,	loss: 3.2,	training_step: 7.46e+03
# INFO:TrainMonitor:ep: 34,	T: 7,676,	G: -383,	avg_r: -2.62,	avg_G: -117,	t: 146,	dt: 28.604ms,	v: -60.9,	Rn: -177,	loss: 3.19,	training_step: 7.61e+03
# INFO:TrainMonitor:ep: 35,	T: 7,937,	G: -182,	avg_r: -0.702,	avg_G: -124,	t: 260,	dt: 28.947ms,	v: -51.9,	Rn: -77.6,	loss: 3.18,	training_step: 7.87e+03
# INFO:TrainMonitor:ep: 36,	T: 8,101,	G: -190,	avg_r: -1.17,	avg_G: -130,	t: 163,	dt: 29.484ms,	v: -58.7,	Rn: -105,	loss: 3.22,	training_step: 8.03e+03
# INFO:TrainMonitor:ep: 37,	T: 8,249,	G: -47.7,	avg_r: -0.325,	avg_G: -122,	t: 147,	dt: 29.881ms,	v: -45.9,	Rn: -51.9,	loss: 3.2,	training_step: 8.18e+03
# INFO:TrainMonitor:ep: 38,	T: 9,250,	G: 128,	avg_r: 0.128,	avg_G: -97,	t: 1000,	dt: 32.008ms,	v: -45.3,	Rn: 12.6,	loss: 3.2,	training_step: 9.17e+03
# INFO:TrainMonitor:ep: 39,	T: 9,508,	G: 15.2,	avg_r: 0.0592,	avg_G: -85.8,	t: 257,	dt: 30.567ms,	v: -40.8,	Rn: -32.3,	loss: 3.19,	training_step: 9.43e+03
# INFO:TrainMonitor:ep: 40,	T: 9,601,	G: -0.1,	avg_r: -0.00109,	avg_G: -77.2,	t: 92,	dt: 28.858ms,	v: -45.5,	Rn: -36.1,	loss: 3.16,	training_step: 9.52e+03
# INFO:TrainMonitor:ep: 41,	T: 9,817,	G: 62.8,	avg_r: 0.292,	avg_G: -63.2,	t: 215,	dt: 34.359ms,	v: -47.7,	Rn: -25.8,	loss: 3.18,	training_step: 9.74e+03,	test_G: -432
# INFO:TrainMonitor:ep: 42,	T: 10,818,	G: 60.9,	avg_r: 0.0609,	avg_G: -50.8,	t: 1000,	dt: 31.929ms,	v: -25.3,	Rn: 28.7,	loss: 3.2,	training_step: 1.07e+04
# INFO:TrainMonitor:ep: 43,	T: 10,947,	G: -306,	avg_r: -2.39,	avg_G: -76.4,	t: 128,	dt: 45.281ms,	v: -76.3,	Rn: -175,	loss: 3.21,	training_step: 1.09e+04
# INFO:TrainMonitor:ep: 44,	T: 11,413,	G: -182,	avg_r: -0.392,	avg_G: -87,	t: 465,	dt: 31.377ms,	v: -32.2,	Rn: -47.8,	loss: 3.18,	training_step: 1.13e+04
# INFO:TrainMonitor:ep: 45,	T: 11,835,	G: 218,	avg_r: 0.519,	avg_G: -56.4,	t: 421,	dt: 30.530ms,	v: -24.3,	Rn: 3.23,	loss: 3.23,	training_step: 1.17e+04
# INFO:TrainMonitor:ep: 46,	T: 12,012,	G: 47.8,	avg_r: 0.271,	avg_G: -46,	t: 176,	dt: 30.863ms,	v: -44,	Rn: -24,	loss: 3.22,	training_step: 1.19e+04
# INFO:TrainMonitor:ep: 47,	T: 12,203,	G: -49.6,	avg_r: -0.261,	avg_G: -46.4,	t: 190,	dt: 30.417ms,	v: -35,	Rn: -42.5,	loss: 3.21,	training_step: 1.21e+04
# INFO:TrainMonitor:ep: 48,	T: 12,476,	G: -229,	avg_r: -0.841,	avg_G: -64.6,	t: 272,	dt: 30.728ms,	v: -46.8,	Rn: -82.7,	loss: 3.27,	training_step: 1.24e+04
# INFO:TrainMonitor:ep: 49,	T: 12,584,	G: 38.3,	avg_r: 0.358,	avg_G: -54.3,	t: 107,	dt: 29.167ms,	v: -37,	Rn: -14.4,	loss: 3.29,	training_step: 1.25e+04
# INFO:TrainMonitor:ep: 50,	T: 13,585,	G: 156,	avg_r: 0.156,	avg_G: -33.3,	t: 1000,	dt: 34.287ms,	v: -27.2,	Rn: 31.2,	loss: 3.22,	training_step: 1.35e+04
# INFO:TrainMonitor:ep: 51,	T: 13,840,	G: -85.7,	avg_r: -0.337,	avg_G: -38.5,	t: 254,	dt: 57.260ms,	v: -40.9,	Rn: -53.7,	loss: 3.25,	training_step: 1.37e+04,	test_G: -81.1
# INFO:TrainMonitor:ep: 52,	T: 13,939,	G: -27.2,	avg_r: -0.278,	avg_G: -37.4,	t: 98,	dt: 32.879ms,	v: -40,	Rn: -39.4,	loss: 3.27,	training_step: 1.38e+04
# INFO:TrainMonitor:ep: 53,	T: 14,061,	G: 48.8,	avg_r: 0.403,	avg_G: -28.8,	t: 121,	dt: 32.917ms,	v: -33.8,	Rn: -6.91,	loss: 3.27,	training_step: 1.4e+04
# INFO:TrainMonitor:ep: 54,	T: 14,452,	G: -104,	avg_r: -0.267,	avg_G: -36.3,	t: 390,	dt: 39.847ms,	v: -41.5,	Rn: -52.4,	loss: 3.25,	training_step: 1.43e+04
# INFO:TrainMonitor:ep: 55,	T: 14,672,	G: 18.9,	avg_r: 0.0863,	avg_G: -30.8,	t: 219,	dt: 32.434ms,	v: -55.4,	Rn: -45.3,	loss: 3.24,	training_step: 1.46e+04
# INFO:TrainMonitor:ep: 56,	T: 14,834,	G: 28.4,	avg_r: 0.176,	avg_G: -24.9,	t: 161,	dt: 33.215ms,	v: -33.7,	Rn: -24.1,	loss: 3.26,	training_step: 1.47e+04
# INFO:TrainMonitor:ep: 57,	T: 15,000,	G: 53.6,	avg_r: 0.325,	avg_G: -17,	t: 165,	dt: 31.256ms,	v: -31.1,	Rn: -11.7,	loss: 3.24,	training_step: 1.49e+04
# INFO:TrainMonitor:ep: 58,	T: 15,214,	G: -355,	avg_r: -1.67,	avg_G: -50.8,	t: 213,	dt: 31.380ms,	v: -46.2,	Rn: -118,	loss: 3.3,	training_step: 1.51e+04
# INFO:TrainMonitor:ep: 59,	T: 15,374,	G: 33.2,	avg_r: 0.209,	avg_G: -42.4,	t: 159,	dt: 30.797ms,	v: -30.8,	Rn: -19.9,	loss: 3.27,	training_step: 1.53e+04
# INFO:TrainMonitor:ep: 60,	T: 15,501,	G: 27.3,	avg_r: 0.217,	avg_G: -35.4,	t: 126,	dt: 31.472ms,	v: -31.5,	Rn: -16.5,	loss: 3.29,	training_step: 1.54e+04
# INFO:TrainMonitor:ep: 61,	T: 15,696,	G: 24.7,	avg_r: 0.127,	avg_G: -29.4,	t: 194,	dt: 74.823ms,	v: -34.5,	Rn: -28.1,	loss: 3.27,	training_step: 1.56e+04,	test_G: -399
# INFO:TrainMonitor:ep: 62,	T: 16,697,	G: 61.6,	avg_r: 0.0616,	avg_G: -20.3,	t: 1000,	dt: 39.303ms,	v: -20.8,	Rn: 31.8,	loss: 3.29,	training_step: 1.66e+04
# INFO:TrainMonitor:ep: 63,	T: 17,472,	G: 192,	avg_r: 0.248,	avg_G: 0.92,	t: 774,	dt: 35.179ms,	v: -19.9,	Rn: -7.1,	loss: 3.29,	training_step: 1.73e+04
# INFO:TrainMonitor:ep: 64,	T: 17,605,	G: 29.1,	avg_r: 0.22,	avg_G: 3.74,	t: 132,	dt: 34.278ms,	v: -16.9,	Rn: -6.58,	loss: 3.3,	training_step: 1.75e+04
# INFO:TrainMonitor:ep: 65,	T: 18,278,	G: -74.4,	avg_r: -0.111,	avg_G: -4.08,	t: 672,	dt: 35.712ms,	v: -35.3,	Rn: -39.7,	loss: 3.29,	training_step: 1.81e+04
# INFO:TrainMonitor:ep: 66,	T: 18,752,	G: 243,	avg_r: 0.513,	avg_G: 20.6,	t: 473,	dt: 35.055ms,	v: -33.1,	Rn: -4.03,	loss: 3.31,	training_step: 1.86e+04
# INFO:TrainMonitor:ep: 67,	T: 18,889,	G: -55.8,	avg_r: -0.41,	avg_G: 12.9,	t: 136,	dt: 37.121ms,	v: -31,	Rn: -50.9,	loss: 3.31,	training_step: 1.88e+04
# INFO:TrainMonitor:ep: 68,	T: 19,042,	G: 42.5,	avg_r: 0.279,	avg_G: 15.9,	t: 152,	dt: 35.400ms,	v: -16.6,	Rn: -4.33,	loss: 3.31,	training_step: 1.89e+04
# INFO:TrainMonitor:ep: 69,	T: 19,220,	G: 5.9,	avg_r: 0.0333,	avg_G: 14.9,	t: 177,	dt: 45.402ms,	v: -20.6,	Rn: -20.5,	loss: 3.28,	training_step: 1.91e+04
# INFO:TrainMonitor:ep: 70,	T: 19,755,	G: 188,	avg_r: 0.352,	avg_G: 32.2,	t: 534,	dt: 36.435ms,	v: -21.8,	Rn: -2.99,	loss: 3.32,	training_step: 1.96e+04
# INFO:TrainMonitor:ep: 71,	T: 19,970,	G: -146,	avg_r: -0.685,	avg_G: 14.3,	t: 214,	dt: 49.625ms,	v: -29.8,	Rn: -64.4,	loss: 3.3,	training_step: 1.98e+04,	test_G: -91.5
# INFO:TrainMonitor:ep: 72,	T: 20,114,	G: 41.9,	avg_r: 0.293,	avg_G: 17.1,	t: 143,	dt: 33.612ms,	v: -9.48,	Rn: 1.43,	loss: 3.35,	training_step: 2e+04
# INFO:TrainMonitor:ep: 73,	T: 20,621,	G: -190,	avg_r: -0.375,	avg_G: -3.57,	t: 506,	dt: 36.617ms,	v: -25.3,	Rn: -43.2,	loss: 3.35,	training_step: 2.05e+04
# INFO:TrainMonitor:ep: 74,	T: 20,923,	G: 1.69,	avg_r: 0.00562,	avg_G: -3.05,	t: 301,	dt: 53.385ms,	v: -24.4,	Rn: -25,	loss: 3.32,	training_step: 2.08e+04
# INFO:TrainMonitor:ep: 75,	T: 21,089,	G: -48.9,	avg_r: -0.296,	avg_G: -7.63,	t: 165,	dt: 38.827ms,	v: -26.8,	Rn: -42.2,	loss: 3.37,	training_step: 2.09e+04
# INFO:TrainMonitor:ep: 76,	T: 21,447,	G: 32.3,	avg_r: 0.0904,	avg_G: -3.64,	t: 357,	dt: 37.955ms,	v: -28.2,	Rn: -21.7,	loss: 3.34,	training_step: 2.13e+04
# INFO:TrainMonitor:ep: 77,	T: 21,628,	G: -38.5,	avg_r: -0.214,	avg_G: -7.12,	t: 180,	dt: 35.373ms,	v: -23.5,	Rn: -35.4,	loss: 3.32,	training_step: 2.15e+04
# INFO:TrainMonitor:ep: 78,	T: 21,868,	G: 6.7,	avg_r: 0.028,	avg_G: -5.74,	t: 239,	dt: 37.040ms,	v: -20,	Rn: -19.5,	loss: 3.38,	training_step: 2.17e+04
# INFO:TrainMonitor:ep: 79,	T: 22,084,	G: -78.4,	avg_r: -0.365,	avg_G: -13,	t: 215,	dt: 36.372ms,	v: -21.1,	Rn: -39.2,	loss: 3.36,	training_step: 2.19e+04
# INFO:TrainMonitor:ep: 80,	T: 22,282,	G: 36.1,	avg_r: 0.183,	avg_G: -8.09,	t: 197,	dt: 44.950ms,	v: -20.5,	Rn: -14.5,	loss: 3.34,	training_step: 2.21e+04
# INFO:TrainMonitor:ep: 81,	T: 22,995,	G: 223,	avg_r: 0.313,	avg_G: 15,	t: 712,	dt: 44.357ms,	v: -17.6,	Rn: -2.85,	loss: 3.35,	training_step: 2.28e+04,	test_G: -340
# INFO:TrainMonitor:ep: 82,	T: 23,491,	G: -389,	avg_r: -0.786,	avg_G: -25.4,	t: 495,	dt: 35.704ms,	v: -45.9,	Rn: -82.2,	loss: 3.35,	training_step: 2.33e+04
# INFO:TrainMonitor:ep: 83,	T: 24,055,	G: 222,	avg_r: 0.395,	avg_G: -0.663,	t: 563,	dt: 39.382ms,	v: -18.7,	Rn: 0.413,	loss: 3.36,	training_step: 2.39e+04
# INFO:TrainMonitor:ep: 84,	T: 24,246,	G: -6.86,	avg_r: -0.0361,	avg_G: -1.28,	t: 190,	dt: 38.151ms,	v: -21.1,	Rn: -20.9,	loss: 3.35,	training_step: 2.41e+04
# INFO:TrainMonitor:ep: 85,	T: 24,415,	G: 51.2,	avg_r: 0.305,	avg_G: 3.97,	t: 168,	dt: 36.852ms,	v: -6.65,	Rn: 4.04,	loss: 3.37,	training_step: 2.42e+04
# INFO:TrainMonitor:ep: 86,	T: 24,620,	G: 34.6,	avg_r: 0.17,	avg_G: 7.03,	t: 204,	dt: 37.694ms,	v: -14.4,	Rn: -7,	loss: 3.38,	training_step: 2.44e+04
# INFO:TrainMonitor:ep: 87,	T: 25,030,	G: 244,	avg_r: 0.596,	avg_G: 30.7,	t: 409,	dt: 38.556ms,	v: -24.9,	Rn: 4.1,	loss: 3.38,	training_step: 2.49e+04
# INFO:TrainMonitor:ep: 88,	T: 25,314,	G: -28.9,	avg_r: -0.102,	avg_G: 24.7,	t: 283,	dt: 43.956ms,	v: -13,	Rn: -19.9,	loss: 3.37,	training_step: 2.51e+04
# INFO:TrainMonitor:ep: 89,	T: 25,854,	G: -486,	avg_r: -0.903,	avg_G: -26.4,	t: 539,	dt: 37.276ms,	v: -31.3,	Rn: -74.2,	loss: 3.38,	training_step: 2.57e+04
# INFO:TrainMonitor:ep: 90,	T: 26,855,	G: 164,	avg_r: 0.164,	avg_G: -7.33,	t: 1000,	dt: 41.707ms,	v: -27.7,	Rn: 29.7,	loss: 3.38,	training_step: 2.67e+04
# INFO:TrainMonitor:ep: 91,	T: 27,389,	G: 224,	avg_r: 0.42,	avg_G: 15.8,	t: 533,	dt: 50.137ms,	v: -20.8,	Rn: 0.00137,	loss: 3.38,	training_step: 2.72e+04,	test_G: -34.8
# INFO:TrainMonitor:ep: 92,	T: 27,861,	G: 231,	avg_r: 0.491,	avg_G: 37.3,	t: 471,	dt: 37.557ms,	v: -14.9,	Rn: 9.39,	loss: 3.38,	training_step: 2.77e+04
# INFO:TrainMonitor:ep: 93,	T: 28,862,	G: 126,	avg_r: 0.126,	avg_G: 46.2,	t: 1000,	dt: 42.003ms,	v: -8.7,	Rn: 46.1,	loss: 3.4,	training_step: 2.87e+04
# INFO:TrainMonitor:ep: 94,	T: 29,093,	G: 11.8,	avg_r: 0.0514,	avg_G: 42.8,	t: 230,	dt: 38.983ms,	v: -17.6,	Rn: -15,	loss: 3.41,	training_step: 2.89e+04
# INFO:TrainMonitor:ep: 95,	T: 29,338,	G: -319,	avg_r: -1.31,	avg_G: 6.6,	t: 244,	dt: 40.498ms,	v: -40.3,	Rn: -103,	loss: 3.39,	training_step: 2.91e+04
# INFO:TrainMonitor:ep: 96,	T: 30,339,	G: 162,	avg_r: 0.162,	avg_G: 22.1,	t: 1000,	dt: 42.504ms,	v: -15.5,	Rn: 41.5,	loss: 3.4,	training_step: 3.01e+04
# INFO:TrainMonitor:ep: 97,	T: 30,576,	G: -105,	avg_r: -0.445,	avg_G: 9.39,	t: 236,	dt: 53.499ms,	v: -25.3,	Rn: -48.6,	loss: 3.41,	training_step: 3.04e+04
# INFO:TrainMonitor:ep: 98,	T: 31,097,	G: -312,	avg_r: -0.6,	avg_G: -22.8,	t: 520,	dt: 43.499ms,	v: -40.8,	Rn: -68.2,	loss: 3.4,	training_step: 3.09e+04
# INFO:TrainMonitor:ep: 99,	T: 31,332,	G: 49.1,	avg_r: 0.21,	avg_G: -15.6,	t: 234,	dt: 43.299ms,	v: -13.6,	Rn: -6.41,	loss: 3.4,	training_step: 3.11e+04
# INFO:TrainMonitor:ep: 100,	T: 31,609,	G: 16,	avg_r: 0.0578,	avg_G: -12.4,	t: 276,	dt: 40.329ms,	v: -10.8,	Rn: -10.1,	loss: 3.41,	training_step: 3.14e+04
# INFO:TrainMonitor:ep: 101,	T: 31,822,	G: 34.4,	avg_r: 0.162,	avg_G: -7.75,	t: 212,	dt: 107.936ms,	v: -8.72,	Rn: -4.02,	loss: 3.39,	training_step: 3.16e+04,	test_G: -92.9
# INFO:TrainMonitor:ep: 102,	T: 32,823,	G: -164,	avg_r: -0.164,	avg_G: -23.4,	t: 1000,	dt: 44.954ms,	v: -33.1,	Rn: 9.43,	loss: 3.42,	training_step: 3.26e+04
# INFO:TrainMonitor:ep: 103,	T: 33,824,	G: 127,	avg_r: 0.127,	avg_G: -8.34,	t: 1000,	dt: 46.624ms,	v: -8.54,	Rn: 47.6,	loss: 3.41,	training_step: 3.36e+04
# INFO:TrainMonitor:ep: 104,	T: 34,825,	G: 158,	avg_r: 0.158,	avg_G: 8.34,	t: 1000,	dt: 44.935ms,	v: -12.9,	Rn: 43.4,	loss: 3.43,	training_step: 3.46e+04
# INFO:TrainMonitor:ep: 105,	T: 35,046,	G: 10.2,	avg_r: 0.0464,	avg_G: 8.53,	t: 220,	dt: 40.012ms,	v: -6.48,	Rn: -8.4,	loss: 3.38,	training_step: 3.48e+04
# INFO:TrainMonitor:ep: 106,	T: 36,047,	G: 151,	avg_r: 0.151,	avg_G: 22.8,	t: 1000,	dt: 44.436ms,	v: -12.6,	Rn: 43.3,	loss: 3.42,	training_step: 3.58e+04
# INFO:TrainMonitor:ep: 107,	T: 36,294,	G: -130,	avg_r: -0.527,	avg_G: 7.55,	t: 246,	dt: 44.039ms,	v: -16.2,	Rn: -44.1,	loss: 3.44,	training_step: 3.61e+04
# INFO:TrainMonitor:ep: 108,	T: 36,473,	G: 18.7,	avg_r: 0.105,	avg_G: 8.66,	t: 178,	dt: 42.091ms,	v: -9.81,	Rn: -7.87,	loss: 3.44,	training_step: 3.63e+04
# INFO:TrainMonitor:ep: 109,	T: 36,756,	G: -17.4,	avg_r: -0.0618,	avg_G: 6.05,	t: 282,	dt: 45.002ms,	v: -11.4,	Rn: -17.4,	loss: 3.43,	training_step: 3.65e+04
# INFO:TrainMonitor:ep: 110,	T: 37,757,	G: 17.5,	avg_r: 0.0175,	avg_G: 7.2,	t: 1000,	dt: 46.691ms,	v: -8.64,	Rn: 41,	loss: 3.44,	training_step: 3.75e+04
# INFO:TrainMonitor:ep: 111,	T: 38,016,	G: -111,	avg_r: -0.43,	avg_G: -4.61,	t: 258,	dt: 63.377ms,	v: -35.8,	Rn: -58.8,	loss: 3.44,	training_step: 3.78e+04,	test_G: -101
# INFO:TrainMonitor:ep: 112,	T: 38,409,	G: -167,	avg_r: -0.426,	avg_G: -20.8,	t: 392,	dt: 44.647ms,	v: -34.6,	Rn: -55.9,	loss: 3.46,	training_step: 3.82e+04
# INFO:TrainMonitor:ep: 113,	T: 38,775,	G: 229,	avg_r: 0.628,	avg_G: 4.18,	t: 365,	dt: 49.319ms,	v: -6.17,	Rn: 23.3,	loss: 3.42,	training_step: 3.85e+04
# INFO:TrainMonitor:ep: 114,	T: 39,024,	G: -84.2,	avg_r: -0.34,	avg_G: -4.66,	t: 248,	dt: 42.377ms,	v: -10.7,	Rn: -31,	loss: 3.44,	training_step: 3.88e+04
# INFO:TrainMonitor:ep: 115,	T: 39,345,	G: -55,	avg_r: -0.172,	avg_G: -9.7,	t: 320,	dt: 41.345ms,	v: -24.8,	Rn: -34.6,	loss: 3.44,	training_step: 3.91e+04
# INFO:TrainMonitor:ep: 116,	T: 39,576,	G: -42.5,	avg_r: -0.185,	avg_G: -13,	t: 230,	dt: 45.967ms,	v: -16.7,	Rn: -28.9,	loss: 3.47,	training_step: 3.93e+04
# INFO:TrainMonitor:ep: 117,	T: 39,998,	G: 205,	avg_r: 0.486,	avg_G: 8.78,	t: 421,	dt: 49.240ms,	v: -21.9,	Rn: 1.33,	loss: 3.45,	training_step: 3.98e+04

# %%
model_path
# Out:
# '/home/fangbowen/models/LunarLander/epoch_0090_test_G_-34.79156123/lunarlander_model_params'

# %%
model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=discount,
                    optimizer=gradient_transform, support_size=support_size)

model.load(model_path)

# %%
import gymnasium as gym 
from muax.test import test
env_id = 'LunarLander-v2'
test_env = gym.make(env_id, render_mode='rgb_array')
test_key = jax.random.PRNGKey(0)
test(model, test_env, test_key, num_simulations=50, num_test_episodes=100, random_seed=None)
# Out:
# 48.28451863343125
