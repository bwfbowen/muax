# %%
# !pip install muax==0.0.2.7.1b0
# Out:
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# Collecting muax==0.0.2.7.1b0
#   Downloading muax-0.0.2.7.1b0-py3-none-any.whl (20 kB)
# Requirement already satisfied: gymnasium in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1b0) (0.27.1)
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1b0) (2.5.1)
# Requirement already satisfied: optax in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1b0) (0.1.4)
# Requirement already satisfied: dm-haiku in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1b0) (0.0.9)
# Requirement already satisfied: lz4 in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1b0) (4.0.2)
# Requirement already satisfied: mctx in /opt/conda/lib/python3.7/site-packages (from muax==0.0.2.7.1b0) (0.0.2)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1b0) (0.9.0)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1b0) (1.21.6)
# Requirement already satisfied: jmp>=0.0.2 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1b0) (0.0.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1b0) (4.4.0)
# Requirement already satisfied: absl-py>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from dm-haiku->muax==0.0.2.7.1b0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1b0) (5.1.0)
# Requirement already satisfied: gymnasium-notices>=0.0.1 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1b0) (0.0.1)
# Requirement already satisfied: jax-jumpy>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1b0) (0.2.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.7/site-packages (from gymnasium->muax==0.0.2.7.1b0) (2.2.0)
# Requirement already satisfied: jax>=0.1.55 in /opt/conda/lib/python3.7/site-packages (from mctx->muax==0.0.2.7.1b0) (0.3.25)
# Requirement already satisfied: chex>=0.0.8 in /opt/conda/lib/python3.7/site-packages (from mctx->muax==0.0.2.7.1b0) (0.1.5)
# Requirement already satisfied: jaxlib>=0.1.37 in /opt/conda/lib/python3.7/site-packages (from mctx->muax==0.0.2.7.1b0) (0.3.25+cuda11.cudnn82)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /opt/conda/lib/python3.7/site-packages (from tensorboardX->muax==0.0.2.7.1b0) (3.19.6)
# Requirement already satisfied: dm-tree>=0.1.5 in /opt/conda/lib/python3.7/site-packages (from chex>=0.0.8->mctx->muax==0.0.2.7.1b0) (0.1.7)
# Requirement already satisfied: toolz>=0.9.0 in /opt/conda/lib/python3.7/site-packages (from chex>=0.0.8->mctx->muax==0.0.2.7.1b0) (0.12.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=4.8.0->gymnasium->muax==0.0.2.7.1b0) (3.11.0)
# Requirement already satisfied: opt-einsum in /opt/conda/lib/python3.7/site-packages (from jax>=0.1.55->mctx->muax==0.0.2.7.1b0) (3.3.0)
# Requirement already satisfied: scipy>=1.5 in /opt/conda/lib/python3.7/site-packages (from jax>=0.1.55->mctx->muax==0.0.2.7.1b0) (1.7.3)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# Installing collected packages: muax
#   Attempting uninstall: muax
#     WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
#     WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
#     Found existing installation: muax 0.0.2.7.1a0
#     Uninstalling muax-0.0.2.7.1a0:
#       Successfully uninstalled muax-0.0.2.7.1a0
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# Successfully installed muax-0.0.2.7.1b0
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ygame (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -axlib (/opt/conda/lib/python3.7/site-packages)

# %%
import jax 
from jax import numpy as jnp
jax.config.update('jax_platform_name', 'cpu')

import muax
from muax import nn

# %%
import haiku as hk

class Representation(hk.Module):
  def __init__(self, embedding_dim, name='representation'):
    super().__init__(name=name)

    self.repr_func = hk.Sequential([
        hk.Linear(embedding_dim)
    ])

  def __call__(self, obs):
    s = self.repr_func(obs)
    return s 


class Prediction(hk.Module):
  def __init__(self, num_actions, full_support_size, name='prediction'):
    super().__init__(name=name)        
    
    self.v_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.pi_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(num_actions)
    ])
  
  def __call__(self, s):
    v = self.v_func(s)
    logits = self.pi_func(s)
    logits = jax.nn.softmax(logits, axis=-1)
    return v, logits


class Dynamic(hk.Module):
  def __init__(self, embedding_dim, num_actions, full_support_size, name='dynamic'):
    super().__init__(name=name)
    
    self.ns_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(embedding_dim)
    ])
    self.r_func = hk.Sequential([
        hk.Linear(64), jax.nn.elu,
        hk.Linear(full_support_size)
    ])
    self.cat_func = jax.jit(lambda s, a: 
                            jnp.concatenate([s, jax.nn.one_hot(a, num_actions)],
                                            axis=1)
                            )
  
  def __call__(self, s, a):
    sa = self.cat_func(s, a)
    r = self.r_func(sa)
    ns = self.ns_func(sa)
    return r, ns


def init_representation_func(representation_module, embedding_dim):
    def representation_func(obs):
      repr_model = representation_module(embedding_dim)
      return repr_model(obs)
    return representation_func
  
def init_prediction_func(prediction_module, num_actions, full_support_size):
  def prediction_func(s):
    pred_model = prediction_module(num_actions, full_support_size)
    return pred_model(s)
  return prediction_func

def init_dynamic_func(dynamic_module, embedding_dim, num_actions, full_support_size):
  def dynamic_func(s, a):
    dy_model = dynamic_module(embedding_dim, num_actions, full_support_size)
    return dy_model(s, a)
  return dynamic_func

# %%
support_size = 10 
embedding_size = 10
discount = 0.999
num_actions = 4
full_support_size = int(support_size * 2 + 1)

repr_fn = init_representation_func(Representation, embedding_size)
pred_fn = init_prediction_func(Prediction, num_actions, full_support_size)
dy_fn = init_dynamic_func(Dynamic, embedding_size, num_actions, full_support_size)

tracer = muax.PNStep(50, discount, 0.5)
buffer = muax.TrajectoryReplayBuffer(500)

gradient_transform = muax.model.optimizer(init_value=0.005, peak_value=0.005, end_value=0.005, warmup_steps=20000, transition_steps=20000)

# %%
model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=discount,
                    optimizer=gradient_transform, support_size=support_size)

model_path = muax.fit(model, 'LunarLander-v2', 
                    max_episodes=1000,
                    max_training_steps=40000,
                    tracer=tracer,
                    buffer=buffer,
                    k_steps=10,
                    sample_per_trajectory=1,
                    num_trajectory=32,
                    tensorboard_dir='/home/fangbowen/tensorboard/LunarLander',
                    model_save_path='/home/fangbowen/models/LunarLander',
                    save_name='lunarlander_model_params',
                    random_seed=0,
                    log_all_metrics=True)
# Out:
# buffer warm up stage...
# start training...
# INFO:TrainMonitor:ep: 1,	T: 58,	G: -186,	avg_r: -3.26,	avg_G: -186,	t: 57,	dt: 157.692ms,	v: -2.31,	Rn: -131,	loss: 3.97,	training_step: 56,	test_G: -595
# INFO:TrainMonitor:ep: 2,	T: 121,	G: -104,	avg_r: -1.68,	avg_G: -145,	t: 62,	dt: 23.427ms,	v: -65.1,	Rn: -91.8,	loss: 3.73,	training_step: 117
# INFO:TrainMonitor:ep: 3,	T: 180,	G: -176,	avg_r: -3.04,	avg_G: -155,	t: 58,	dt: 23.121ms,	v: -65.5,	Rn: -143,	loss: 3.66,	training_step: 174
# INFO:TrainMonitor:ep: 4,	T: 241,	G: -200,	avg_r: -3.34,	avg_G: -167,	t: 60,	dt: 23.328ms,	v: -79.7,	Rn: -160,	loss: 3.62,	training_step: 233
# INFO:TrainMonitor:ep: 5,	T: 297,	G: -136,	avg_r: -2.47,	avg_G: -161,	t: 55,	dt: 23.004ms,	v: -72.1,	Rn: -114,	loss: 3.52,	training_step: 287
# INFO:TrainMonitor:ep: 6,	T: 362,	G: -38.9,	avg_r: -0.608,	avg_G: -140,	t: 64,	dt: 23.243ms,	v: -87.6,	Rn: -54.5,	loss: 3.54,	training_step: 350
# INFO:TrainMonitor:ep: 7,	T: 437,	G: -88.6,	avg_r: -1.2,	avg_G: -133,	t: 74,	dt: 23.054ms,	v: -60.7,	Rn: -86.9,	loss: 3.48,	training_step: 423
# INFO:TrainMonitor:ep: 8,	T: 498,	G: -220,	avg_r: -3.66,	avg_G: -144,	t: 60,	dt: 23.629ms,	v: -81.4,	Rn: -182,	loss: 3.43,	training_step: 482
# INFO:TrainMonitor:ep: 9,	T: 564,	G: -28.9,	avg_r: -0.445,	avg_G: -131,	t: 65,	dt: 23.460ms,	v: -90.2,	Rn: -46.8,	loss: 3.46,	training_step: 546
# INFO:TrainMonitor:ep: 10,	T: 626,	G: -65.7,	avg_r: -1.08,	avg_G: -124,	t: 61,	dt: 23.090ms,	v: -81.5,	Rn: -73,	loss: 3.45,	training_step: 606
# INFO:TrainMonitor:ep: 11,	T: 684,	G: -67.3,	avg_r: -1.18,	avg_G: -119,	t: 57,	dt: 41.748ms,	v: -81.5,	Rn: -70.3,	loss: 3.45,	training_step: 662,	test_G: -450
# INFO:TrainMonitor:ep: 12,	T: 747,	G: -86,	avg_r: -1.39,	avg_G: -115,	t: 62,	dt: 23.481ms,	v: -63.6,	Rn: -72.5,	loss: 3.42,	training_step: 723
# INFO:TrainMonitor:ep: 13,	T: 853,	G: 57.9,	avg_r: 0.551,	avg_G: -98.1,	t: 105,	dt: 22.937ms,	v: -75.2,	Rn: -15.6,	loss: 3.4,	training_step: 827
# INFO:TrainMonitor:ep: 14,	T: 980,	G: -538,	avg_r: -4.27,	avg_G: -142,	t: 126,	dt: 31.216ms,	v: -63,	Rn: -250,	loss: 3.39,	training_step: 952
# INFO:TrainMonitor:ep: 15,	T: 1,041,	G: -60.9,	avg_r: -1.02,	avg_G: -134,	t: 60,	dt: 38.204ms,	v: -76.8,	Rn: -69.3,	loss: 3.41,	training_step: 1.01e+03
# INFO:TrainMonitor:ep: 16,	T: 1,170,	G: -25.5,	avg_r: -0.2,	avg_G: -123,	t: 128,	dt: 23.247ms,	v: -61.3,	Rn: -52,	loss: 3.34,	training_step: 1.14e+03
# INFO:TrainMonitor:ep: 17,	T: 1,237,	G: -61.1,	avg_r: -0.925,	avg_G: -117,	t: 66,	dt: 23.163ms,	v: -73.3,	Rn: -68.1,	loss: 3.34,	training_step: 1.2e+03
# INFO:TrainMonitor:ep: 18,	T: 2,238,	G: 37.9,	avg_r: 0.0379,	avg_G: -101,	t: 1000,	dt: 25.559ms,	v: -72.4,	Rn: -15.8,	loss: 3.3,	training_step: 2.2e+03
# INFO:TrainMonitor:ep: 19,	T: 2,336,	G: -48.1,	avg_r: -0.496,	avg_G: -96.1,	t: 97,	dt: 24.141ms,	v: -63.5,	Rn: -60.4,	loss: 3.28,	training_step: 2.3e+03
# INFO:TrainMonitor:ep: 20,	T: 2,430,	G: -25.6,	avg_r: -0.275,	avg_G: -89.1,	t: 93,	dt: 24.237ms,	v: -63.5,	Rn: -54.7,	loss: 3.27,	training_step: 2.39e+03
# INFO:TrainMonitor:ep: 21,	T: 2,523,	G: -24,	avg_r: -0.261,	avg_G: -82.6,	t: 92,	dt: 65.162ms,	v: -66.4,	Rn: -51,	loss: 3.27,	training_step: 2.48e+03,	test_G: -567
# INFO:TrainMonitor:ep: 22,	T: 2,595,	G: -28.8,	avg_r: -0.405,	avg_G: -77.2,	t: 71,	dt: 25.756ms,	v: -65.1,	Rn: -47.7,	loss: 3.24,	training_step: 2.55e+03
# INFO:TrainMonitor:ep: 23,	T: 2,668,	G: -37.5,	avg_r: -0.521,	avg_G: -73.2,	t: 72,	dt: 24.972ms,	v: -64.2,	Rn: -54.2,	loss: 3.31,	training_step: 2.62e+03
# INFO:TrainMonitor:ep: 24,	T: 3,669,	G: 57.6,	avg_r: 0.0576,	avg_G: -60.1,	t: 1000,	dt: 30.016ms,	v: -60.9,	Rn: -4.88,	loss: 3.25,	training_step: 3.62e+03
# INFO:TrainMonitor:ep: 25,	T: 3,797,	G: -14,	avg_r: -0.11,	avg_G: -55.5,	t: 127,	dt: 27.563ms,	v: -57.3,	Rn: -47.3,	loss: 3.18,	training_step: 3.75e+03
# INFO:TrainMonitor:ep: 26,	T: 3,869,	G: -45.9,	avg_r: -0.646,	avg_G: -54.6,	t: 71,	dt: 29.973ms,	v: -62.7,	Rn: -59.6,	loss: 3.25,	training_step: 3.82e+03
# INFO:TrainMonitor:ep: 27,	T: 4,277,	G: -8.86,	avg_r: -0.0218,	avg_G: -50,	t: 407,	dt: 29.087ms,	v: -57.8,	Rn: -52,	loss: 3.25,	training_step: 4.22e+03
# INFO:TrainMonitor:ep: 28,	T: 4,742,	G: 5.34,	avg_r: 0.0115,	avg_G: -44.5,	t: 464,	dt: 29.497ms,	v: -42.7,	Rn: -36.7,	loss: 3.25,	training_step: 4.69e+03
# INFO:TrainMonitor:ep: 29,	T: 4,841,	G: -19,	avg_r: -0.194,	avg_G: -41.9,	t: 98,	dt: 29.313ms,	v: -51.7,	Rn: -42.9,	loss: 3.24,	training_step: 4.78e+03
# INFO:TrainMonitor:ep: 30,	T: 5,110,	G: -100,	avg_r: -0.375,	avg_G: -47.8,	t: 268,	dt: 29.659ms,	v: -47.8,	Rn: -58.8,	loss: 3.24,	training_step: 5.05e+03
# INFO:TrainMonitor:ep: 31,	T: 5,476,	G: 12.6,	avg_r: 0.0345,	avg_G: -41.7,	t: 365,	dt: 38.023ms,	v: -48.2,	Rn: -39.9,	loss: 3.25,	training_step: 5.41e+03,	test_G: -401
# INFO:TrainMonitor:ep: 32,	T: 5,608,	G: -5.82,	avg_r: -0.0445,	avg_G: -38.1,	t: 131,	dt: 31.142ms,	v: -43.2,	Rn: -33.7,	loss: 3.24,	training_step: 5.54e+03
# INFO:TrainMonitor:ep: 33,	T: 5,922,	G: -96.7,	avg_r: -0.309,	avg_G: -44,	t: 313,	dt: 31.227ms,	v: -52,	Rn: -59.6,	loss: 3.27,	training_step: 5.86e+03
# INFO:TrainMonitor:ep: 34,	T: 6,269,	G: -194,	avg_r: -0.56,	avg_G: -59,	t: 346,	dt: 31.169ms,	v: -47.5,	Rn: -69.3,	loss: 3.26,	training_step: 6.2e+03
# INFO:TrainMonitor:ep: 35,	T: 6,610,	G: -136,	avg_r: -0.399,	avg_G: -66.6,	t: 340,	dt: 32.298ms,	v: -53.5,	Rn: -66.9,	loss: 3.29,	training_step: 6.54e+03
# INFO:TrainMonitor:ep: 36,	T: 6,873,	G: -120,	avg_r: -0.457,	avg_G: -71.9,	t: 262,	dt: 31.995ms,	v: -50,	Rn: -64,	loss: 3.27,	training_step: 6.8e+03
# INFO:TrainMonitor:ep: 37,	T: 7,196,	G: -392,	avg_r: -1.22,	avg_G: -104,	t: 322,	dt: 37.091ms,	v: -51.7,	Rn: -105,	loss: 3.26,	training_step: 7.12e+03
# INFO:TrainMonitor:ep: 38,	T: 7,302,	G: -15.6,	avg_r: -0.149,	avg_G: -95.1,	t: 105,	dt: 29.833ms,	v: -33.6,	Rn: -30.6,	loss: 3.3,	training_step: 7.23e+03
# INFO:TrainMonitor:ep: 39,	T: 7,574,	G: -55.9,	avg_r: -0.206,	avg_G: -91.2,	t: 271,	dt: 29.850ms,	v: -48.4,	Rn: -50.9,	loss: 3.27,	training_step: 7.5e+03
# INFO:TrainMonitor:ep: 40,	T: 7,812,	G: -124,	avg_r: -0.524,	avg_G: -94.5,	t: 237,	dt: 28.382ms,	v: -47.1,	Rn: -68.2,	loss: 3.28,	training_step: 7.73e+03
# INFO:TrainMonitor:ep: 41,	T: 8,157,	G: -440,	avg_r: -1.28,	avg_G: -129,	t: 344,	dt: 37.529ms,	v: -48.7,	Rn: -108,	loss: 3.27,	training_step: 8.08e+03,	test_G: -292
# INFO:TrainMonitor:ep: 42,	T: 8,425,	G: -54.9,	avg_r: -0.206,	avg_G: -122,	t: 267,	dt: 28.495ms,	v: -44.7,	Rn: -50.4,	loss: 3.29,	training_step: 8.34e+03
# INFO:TrainMonitor:ep: 43,	T: 8,726,	G: -112,	avg_r: -0.374,	avg_G: -121,	t: 300,	dt: 29.828ms,	v: -53,	Rn: -66.6,	loss: 3.29,	training_step: 8.64e+03
# INFO:TrainMonitor:ep: 44,	T: 8,856,	G: -21.1,	avg_r: -0.164,	avg_G: -111,	t: 129,	dt: 38.597ms,	v: -30.3,	Rn: -31.1,	loss: 3.35,	training_step: 8.77e+03
# INFO:TrainMonitor:ep: 45,	T: 9,153,	G: -205,	avg_r: -0.693,	avg_G: -120,	t: 296,	dt: 31.218ms,	v: -53.2,	Rn: -83.8,	loss: 3.27,	training_step: 9.06e+03
# INFO:TrainMonitor:ep: 46,	T: 10,154,	G: 61.7,	avg_r: 0.0617,	avg_G: -102,	t: 1000,	dt: 29.982ms,	v: -81.9,	Rn: -25.5,	loss: 3.27,	training_step: 1.01e+04
# INFO:TrainMonitor:ep: 47,	T: 10,356,	G: -245,	avg_r: -1.22,	avg_G: -116,	t: 201,	dt: 32.210ms,	v: -43.2,	Rn: -100,	loss: 3.26,	training_step: 1.03e+04
# INFO:TrainMonitor:ep: 48,	T: 10,675,	G: -81.5,	avg_r: -0.256,	avg_G: -113,	t: 318,	dt: 32.036ms,	v: -58.1,	Rn: -66.7,	loss: 3.27,	training_step: 1.06e+04
# INFO:TrainMonitor:ep: 49,	T: 10,909,	G: -47,	avg_r: -0.202,	avg_G: -106,	t: 233,	dt: 41.882ms,	v: -45.5,	Rn: -51.7,	loss: 3.26,	training_step: 1.08e+04
# INFO:TrainMonitor:ep: 50,	T: 11,159,	G: 53,	avg_r: 0.213,	avg_G: -90.3,	t: 249,	dt: 31.300ms,	v: -54.5,	Rn: -40.6,	loss: 3.27,	training_step: 1.11e+04
# INFO:TrainMonitor:ep: 51,	T: 11,416,	G: -187,	avg_r: -0.731,	avg_G: -100,	t: 256,	dt: 40.781ms,	v: -54.1,	Rn: -87,	loss: 3.28,	training_step: 1.13e+04,	test_G: -315
# INFO:TrainMonitor:ep: 52,	T: 11,670,	G: -285,	avg_r: -1.13,	avg_G: -118,	t: 253,	dt: 32.989ms,	v: -53.6,	Rn: -100,	loss: 3.27,	training_step: 1.16e+04
# INFO:TrainMonitor:ep: 53,	T: 11,921,	G: -35.7,	avg_r: -0.143,	avg_G: -110,	t: 250,	dt: 31.534ms,	v: -57.2,	Rn: -56,	loss: 3.26,	training_step: 1.18e+04
# INFO:TrainMonitor:ep: 54,	T: 12,267,	G: -205,	avg_r: -0.595,	avg_G: -120,	t: 345,	dt: 31.026ms,	v: -52.2,	Rn: -76.8,	loss: 3.27,	training_step: 1.22e+04
# INFO:TrainMonitor:ep: 55,	T: 12,389,	G: -14.5,	avg_r: -0.12,	avg_G: -109,	t: 121,	dt: 32.792ms,	v: -36.2,	Rn: -36.2,	loss: 3.28,	training_step: 1.23e+04
# INFO:TrainMonitor:ep: 56,	T: 12,624,	G: -468,	avg_r: -2,	avg_G: -145,	t: 234,	dt: 41.009ms,	v: -49.2,	Rn: -138,	loss: 3.3,	training_step: 1.25e+04
# INFO:TrainMonitor:ep: 57,	T: 12,934,	G: -31.6,	avg_r: -0.102,	avg_G: -134,	t: 309,	dt: 33.845ms,	v: -58.2,	Rn: -57.8,	loss: 3.28,	training_step: 1.28e+04
# INFO:TrainMonitor:ep: 58,	T: 13,037,	G: 1.57,	avg_r: 0.0154,	avg_G: -120,	t: 102,	dt: 33.174ms,	v: -24.8,	Rn: -24.9,	loss: 3.26,	training_step: 1.29e+04
# INFO:TrainMonitor:ep: 59,	T: 13,138,	G: -29,	avg_r: -0.29,	avg_G: -111,	t: 100,	dt: 34.020ms,	v: -42.2,	Rn: -44.6,	loss: 3.28,	training_step: 1.3e+04
# INFO:TrainMonitor:ep: 60,	T: 13,262,	G: 34,	avg_r: 0.276,	avg_G: -96.5,	t: 123,	dt: 34.634ms,	v: -38.4,	Rn: -21.1,	loss: 3.31,	training_step: 1.31e+04
# INFO:TrainMonitor:ep: 61,	T: 13,524,	G: -316,	avg_r: -1.21,	avg_G: -119,	t: 261,	dt: 42.474ms,	v: -57.3,	Rn: -114,	loss: 3.25,	training_step: 1.34e+04,	test_G: -261
# INFO:TrainMonitor:ep: 62,	T: 13,792,	G: -147,	avg_r: -0.551,	avg_G: -121,	t: 267,	dt: 34.714ms,	v: -61.3,	Rn: -83,	loss: 3.31,	training_step: 1.37e+04
# INFO:TrainMonitor:ep: 63,	T: 13,906,	G: -19.3,	avg_r: -0.17,	avg_G: -111,	t: 113,	dt: 33.649ms,	v: -29.5,	Rn: -33.1,	loss: 3.28,	training_step: 1.38e+04
# INFO:TrainMonitor:ep: 64,	T: 14,019,	G: 32,	avg_r: 0.286,	avg_G: -96.9,	t: 112,	dt: 35.210ms,	v: -36.4,	Rn: -16,	loss: 3.26,	training_step: 1.39e+04
# INFO:TrainMonitor:ep: 65,	T: 14,317,	G: -356,	avg_r: -1.2,	avg_G: -123,	t: 297,	dt: 40.391ms,	v: -66.9,	Rn: -122,	loss: 3.27,	training_step: 1.42e+04
# INFO:TrainMonitor:ep: 66,	T: 14,657,	G: -231,	avg_r: -0.682,	avg_G: -134,	t: 339,	dt: 35.137ms,	v: -66,	Rn: -95,	loss: 3.28,	training_step: 1.45e+04
# INFO:TrainMonitor:ep: 67,	T: 14,766,	G: 3.73,	avg_r: 0.0345,	avg_G: -120,	t: 108,	dt: 32.841ms,	v: -43.2,	Rn: -34.4,	loss: 3.28,	training_step: 1.46e+04
# INFO:TrainMonitor:ep: 68,	T: 15,466,	G: 204,	avg_r: 0.292,	avg_G: -87.5,	t: 699,	dt: 33.657ms,	v: -74.1,	Rn: -56.2,	loss: 3.29,	training_step: 1.53e+04
# INFO:TrainMonitor:ep: 69,	T: 16,467,	G: 120,	avg_r: 0.12,	avg_G: -66.7,	t: 1000,	dt: 35.506ms,	v: -53.7,	Rn: 3.7,	loss: 3.3,	training_step: 1.63e+04
# INFO:TrainMonitor:ep: 70,	T: 16,686,	G: 22.3,	avg_r: 0.102,	avg_G: -57.8,	t: 218,	dt: 33.773ms,	v: -54.7,	Rn: -48,	loss: 3.31,	training_step: 1.65e+04
# INFO:TrainMonitor:ep: 71,	T: 16,796,	G: -20.3,	avg_r: -0.186,	avg_G: -54,	t: 109,	dt: 76.270ms,	v: -34.3,	Rn: -31.5,	loss: 3.3,	training_step: 1.67e+04,	test_G: 65.8
# INFO:TrainMonitor:ep: 72,	T: 17,078,	G: -19,	avg_r: -0.0678,	avg_G: -50.5,	t: 281,	dt: 33.819ms,	v: -58.4,	Rn: -56.6,	loss: 3.28,	training_step: 1.69e+04
# INFO:TrainMonitor:ep: 73,	T: 17,285,	G: -35.8,	avg_r: -0.174,	avg_G: -49.1,	t: 206,	dt: 34.299ms,	v: -42.4,	Rn: -44.4,	loss: 3.28,	training_step: 1.71e+04
# INFO:TrainMonitor:ep: 74,	T: 18,037,	G: 189,	avg_r: 0.252,	avg_G: -25.2,	t: 751,	dt: 36.896ms,	v: -49.2,	Rn: -34.3,	loss: 3.31,	training_step: 1.79e+04
# INFO:TrainMonitor:ep: 75,	T: 18,258,	G: -72.1,	avg_r: -0.328,	avg_G: -29.9,	t: 220,	dt: 34.815ms,	v: -53.3,	Rn: -67,	loss: 3.28,	training_step: 1.81e+04
# INFO:TrainMonitor:ep: 76,	T: 18,360,	G: 5.74,	avg_r: 0.0568,	avg_G: -26.4,	t: 101,	dt: 33.350ms,	v: -24,	Rn: -21.3,	loss: 3.31,	training_step: 1.82e+04
# INFO:TrainMonitor:ep: 77,	T: 19,361,	G: 84.3,	avg_r: 0.0843,	avg_G: -15.3,	t: 1000,	dt: 37.263ms,	v: -63.8,	Rn: -8.11,	loss: 3.3,	training_step: 1.92e+04
# INFO:TrainMonitor:ep: 78,	T: 19,483,	G: 53.1,	avg_r: 0.439,	avg_G: -8.47,	t: 121,	dt: 35.052ms,	v: -29.7,	Rn: -9.86,	loss: 3.33,	training_step: 1.93e+04
# INFO:TrainMonitor:ep: 79,	T: 19,734,	G: -27.2,	avg_r: -0.109,	avg_G: -10.3,	t: 250,	dt: 36.569ms,	v: -47.4,	Rn: -52.5,	loss: 3.31,	training_step: 1.96e+04
# INFO:TrainMonitor:ep: 80,	T: 20,022,	G: -59.4,	avg_r: -0.207,	avg_G: -15.2,	t: 287,	dt: 35.619ms,	v: -62.4,	Rn: -69.7,	loss: 3.28,	training_step: 1.99e+04
# INFO:TrainMonitor:ep: 81,	T: 20,738,	G: 218,	avg_r: 0.305,	avg_G: 8.07,	t: 715,	dt: 43.319ms,	v: -42.1,	Rn: -25.2,	loss: 3.3,	training_step: 2.06e+04,	test_G: 3.61
# INFO:TrainMonitor:ep: 82,	T: 20,987,	G: -60.4,	avg_r: -0.243,	avg_G: 1.23,	t: 248,	dt: 52.190ms,	v: -55.7,	Rn: -65,	loss: 3.3,	training_step: 2.08e+04
# INFO:TrainMonitor:ep: 83,	T: 21,234,	G: -69.9,	avg_r: -0.284,	avg_G: -5.88,	t: 246,	dt: 38.693ms,	v: -54.1,	Rn: -65.9,	loss: 3.29,	training_step: 2.11e+04
# INFO:TrainMonitor:ep: 84,	T: 21,464,	G: -9.98,	avg_r: -0.0436,	avg_G: -6.29,	t: 229,	dt: 38.441ms,	v: -50.6,	Rn: -51.5,	loss: 3.31,	training_step: 2.13e+04
# INFO:TrainMonitor:ep: 85,	T: 21,719,	G: -53.6,	avg_r: -0.211,	avg_G: -11,	t: 254,	dt: 36.416ms,	v: -62.5,	Rn: -70.5,	loss: 3.32,	training_step: 2.15e+04
# INFO:TrainMonitor:ep: 86,	T: 21,959,	G: -59.7,	avg_r: -0.25,	avg_G: -15.9,	t: 239,	dt: 37.583ms,	v: -55.9,	Rn: -64.6,	loss: 3.31,	training_step: 2.18e+04
# INFO:TrainMonitor:ep: 87,	T: 22,226,	G: -95.9,	avg_r: -0.361,	avg_G: -23.9,	t: 266,	dt: 43.028ms,	v: -55.9,	Rn: -71.3,	loss: 3.29,	training_step: 2.21e+04
# INFO:TrainMonitor:ep: 88,	T: 22,620,	G: 297,	avg_r: 0.755,	avg_G: 8.17,	t: 393,	dt: 37.227ms,	v: -38.6,	Rn: -0.688,	loss: 3.3,	training_step: 2.24e+04
# INFO:TrainMonitor:ep: 89,	T: 22,751,	G: 28.8,	avg_r: 0.222,	avg_G: 10.2,	t: 130,	dt: 40.415ms,	v: -31.9,	Rn: -20.1,	loss: 3.32,	training_step: 2.26e+04
# INFO:TrainMonitor:ep: 90,	T: 23,014,	G: -109,	avg_r: -0.415,	avg_G: -1.67,	t: 262,	dt: 38.256ms,	v: -61.7,	Rn: -78.7,	loss: 3.31,	training_step: 2.28e+04
# INFO:TrainMonitor:ep: 91,	T: 23,259,	G: -38.3,	avg_r: -0.157,	avg_G: -5.33,	t: 244,	dt: 52.908ms,	v: -55.2,	Rn: -60.1,	loss: 3.31,	training_step: 2.31e+04,	test_G: -17.4
# INFO:TrainMonitor:ep: 92,	T: 23,387,	G: 6.16,	avg_r: 0.0485,	avg_G: -4.18,	t: 127,	dt: 39.272ms,	v: -22.4,	Rn: -24.1,	loss: 3.33,	training_step: 2.32e+04
# INFO:TrainMonitor:ep: 93,	T: 23,652,	G: -113,	avg_r: -0.429,	avg_G: -15.1,	t: 264,	dt: 46.591ms,	v: -59.8,	Rn: -76.8,	loss: 3.32,	training_step: 2.35e+04
# INFO:TrainMonitor:ep: 94,	T: 23,907,	G: -71.2,	avg_r: -0.28,	avg_G: -20.7,	t: 254,	dt: 37.928ms,	v: -52.7,	Rn: -66.2,	loss: 3.31,	training_step: 2.37e+04
# INFO:TrainMonitor:ep: 95,	T: 24,158,	G: -63.9,	avg_r: -0.256,	avg_G: -25,	t: 250,	dt: 37.138ms,	v: -56.7,	Rn: -68.1,	loss: 3.28,	training_step: 2.4e+04
# INFO:TrainMonitor:ep: 96,	T: 24,385,	G: 43.4,	avg_r: 0.192,	avg_G: -18.2,	t: 226,	dt: 38.104ms,	v: -44.7,	Rn: -35,	loss: 3.33,	training_step: 2.42e+04
# INFO:TrainMonitor:ep: 97,	T: 24,943,	G: -11.7,	avg_r: -0.0211,	avg_G: -17.5,	t: 557,	dt: 36.533ms,	v: -43,	Rn: -43,	loss: 3.32,	training_step: 2.47e+04
# INFO:TrainMonitor:ep: 98,	T: 25,191,	G: 42,	avg_r: 0.17,	avg_G: -11.6,	t: 247,	dt: 44.636ms,	v: -47.4,	Rn: -38,	loss: 3.31,	training_step: 2.5e+04
# INFO:TrainMonitor:ep: 99,	T: 25,317,	G: 24.6,	avg_r: 0.197,	avg_G: -7.96,	t: 125,	dt: 36.595ms,	v: -32.6,	Rn: -25.6,	loss: 3.34,	training_step: 2.51e+04
# INFO:TrainMonitor:ep: 100,	T: 25,450,	G: 27.2,	avg_r: 0.206,	avg_G: -4.45,	t: 132,	dt: 34.939ms,	v: -27.9,	Rn: -20.9,	loss: 3.33,	training_step: 2.52e+04
# INFO:TrainMonitor:ep: 101,	T: 25,708,	G: -66.1,	avg_r: -0.257,	avg_G: -10.6,	t: 257,	dt: 39.507ms,	v: -54.4,	Rn: -66.4,	loss: 3.31,	training_step: 2.55e+04,	test_G: -4.12
# INFO:TrainMonitor:ep: 102,	T: 26,709,	G: 161,	avg_r: 0.161,	avg_G: 6.5,	t: 1000,	dt: 38.355ms,	v: -30.5,	Rn: 27.2,	loss: 3.33,	training_step: 2.65e+04
# INFO:TrainMonitor:ep: 103,	T: 27,710,	G: 176,	avg_r: 0.176,	avg_G: 23.4,	t: 1000,	dt: 36.549ms,	v: -45.6,	Rn: 13.5,	loss: 3.32,	training_step: 2.75e+04
# INFO:TrainMonitor:ep: 104,	T: 28,711,	G: 169,	avg_r: 0.169,	avg_G: 38,	t: 1000,	dt: 41.335ms,	v: -34.3,	Rn: 24.2,	loss: 3.34,	training_step: 2.85e+04
# INFO:TrainMonitor:ep: 105,	T: 28,914,	G: 53.9,	avg_r: 0.267,	avg_G: 39.6,	t: 202,	dt: 36.125ms,	v: -46.4,	Rn: -32.7,	loss: 3.32,	training_step: 2.87e+04
# INFO:TrainMonitor:ep: 106,	T: 29,058,	G: 26.2,	avg_r: 0.183,	avg_G: 38.2,	t: 143,	dt: 38.986ms,	v: -32.6,	Rn: -23.9,	loss: 3.31,	training_step: 2.88e+04
# INFO:TrainMonitor:ep: 107,	T: 30,059,	G: 164,	avg_r: 0.164,	avg_G: 50.8,	t: 1000,	dt: 41.122ms,	v: -22.6,	Rn: 35,	loss: 3.33,	training_step: 2.98e+04
# INFO:TrainMonitor:ep: 108,	T: 30,346,	G: -104,	avg_r: -0.365,	avg_G: 35.3,	t: 286,	dt: 37.150ms,	v: -57.1,	Rn: -72.7,	loss: 3.35,	training_step: 3.01e+04
# INFO:TrainMonitor:ep: 109,	T: 30,585,	G: -52.9,	avg_r: -0.222,	avg_G: 26.5,	t: 238,	dt: 55.177ms,	v: -57.9,	Rn: -67.1,	loss: 3.33,	training_step: 3.04e+04
# INFO:TrainMonitor:ep: 110,	T: 30,834,	G: -145,	avg_r: -0.584,	avg_G: 9.35,	t: 248,	dt: 39.990ms,	v: -55.1,	Rn: -80.4,	loss: 3.33,	training_step: 3.06e+04
# INFO:TrainMonitor:ep: 111,	T: 30,982,	G: 35.5,	avg_r: 0.242,	avg_G: 12,	t: 147,	dt: 48.329ms,	v: -33.5,	Rn: -21,	loss: 3.29,	training_step: 3.08e+04,	test_G: -5.95
# INFO:TrainMonitor:ep: 112,	T: 31,215,	G: 45.7,	avg_r: 0.197,	avg_G: 15.3,	t: 232,	dt: 47.909ms,	v: -50.3,	Rn: -36.5,	loss: 3.34,	training_step: 3.1e+04
# INFO:TrainMonitor:ep: 113,	T: 32,216,	G: 168,	avg_r: 0.168,	avg_G: 30.6,	t: 1000,	dt: 39.733ms,	v: -54.1,	Rn: 5.4,	loss: 3.34,	training_step: 3.2e+04
# INFO:TrainMonitor:ep: 114,	T: 32,462,	G: -135,	avg_r: -0.553,	avg_G: 14,	t: 245,	dt: 39.316ms,	v: -53,	Rn: -78.2,	loss: 3.32,	training_step: 3.22e+04
# INFO:TrainMonitor:ep: 115,	T: 32,671,	G: 6.39,	avg_r: 0.0307,	avg_G: 13.3,	t: 208,	dt: 47.160ms,	v: -47.8,	Rn: -45.7,	loss: 3.36,	training_step: 3.24e+04
# INFO:TrainMonitor:ep: 116,	T: 32,944,	G: 29.1,	avg_r: 0.107,	avg_G: 14.9,	t: 272,	dt: 38.146ms,	v: -54,	Rn: -42.5,	loss: 3.34,	training_step: 3.27e+04
# INFO:TrainMonitor:ep: 117,	T: 33,181,	G: 50.2,	avg_r: 0.213,	avg_G: 18.4,	t: 236,	dt: 38.256ms,	v: -49,	Rn: -36.9,	loss: 3.34,	training_step: 3.29e+04
# INFO:TrainMonitor:ep: 118,	T: 33,361,	G: 40.7,	avg_r: 0.227,	avg_G: 20.6,	t: 179,	dt: 38.920ms,	v: -43.4,	Rn: -31.6,	loss: 3.36,	training_step: 3.31e+04
# INFO:TrainMonitor:ep: 119,	T: 33,617,	G: -57.5,	avg_r: -0.226,	avg_G: 12.8,	t: 255,	dt: 38.481ms,	v: -51.8,	Rn: -59.6,	loss: 3.31,	training_step: 3.34e+04
# INFO:TrainMonitor:ep: 120,	T: 33,894,	G: -28.9,	avg_r: -0.105,	avg_G: 8.64,	t: 276,	dt: 38.029ms,	v: -55.3,	Rn: -56.7,	loss: 3.36,	training_step: 3.37e+04
# INFO:TrainMonitor:ep: 121,	T: 34,895,	G: 143,	avg_r: 0.143,	avg_G: 22,	t: 1000,	dt: 41.555ms,	v: -12,	Rn: 44,	loss: 3.34,	training_step: 3.47e+04,	test_G: -9.38
# INFO:TrainMonitor:ep: 122,	T: 35,092,	G: 45.9,	avg_r: 0.234,	avg_G: 24.4,	t: 196,	dt: 38.165ms,	v: -41.2,	Rn: -30.7,	loss: 3.36,	training_step: 3.48e+04
# INFO:TrainMonitor:ep: 123,	T: 35,316,	G: 17.3,	avg_r: 0.0777,	avg_G: 23.7,	t: 223,	dt: 39.864ms,	v: -41.3,	Rn: -36.9,	loss: 3.36,	training_step: 3.51e+04
# INFO:TrainMonitor:ep: 124,	T: 35,551,	G: 32.5,	avg_r: 0.139,	avg_G: 24.6,	t: 234,	dt: 36.981ms,	v: -47.8,	Rn: -38.6,	loss: 3.34,	training_step: 3.53e+04
# INFO:TrainMonitor:ep: 125,	T: 35,767,	G: 54.8,	avg_r: 0.255,	avg_G: 27.6,	t: 215,	dt: 45.991ms,	v: -43.8,	Rn: -32.7,	loss: 3.38,	training_step: 3.55e+04
# INFO:TrainMonitor:ep: 126,	T: 35,992,	G: 35.5,	avg_r: 0.159,	avg_G: 28.4,	t: 224,	dt: 36.552ms,	v: -46.7,	Rn: -38,	loss: 3.34,	training_step: 3.57e+04
# INFO:TrainMonitor:ep: 127,	T: 36,115,	G: -29.7,	avg_r: -0.243,	avg_G: 22.6,	t: 122,	dt: 36.965ms,	v: -26.3,	Rn: -39.5,	loss: 3.33,	training_step: 3.59e+04
# INFO:TrainMonitor:ep: 128,	T: 36,367,	G: -92.4,	avg_r: -0.368,	avg_G: 11.1,	t: 251,	dt: 37.562ms,	v: -53.3,	Rn: -68,	loss: 3.32,	training_step: 3.61e+04
# INFO:TrainMonitor:ep: 129,	T: 36,590,	G: 30.9,	avg_r: 0.139,	avg_G: 13.1,	t: 222,	dt: 37.787ms,	v: -45.3,	Rn: -35.5,	loss: 3.34,	training_step: 3.63e+04
# INFO:TrainMonitor:ep: 130,	T: 36,741,	G: -10.5,	avg_r: -0.0701,	avg_G: 10.7,	t: 150,	dt: 39.374ms,	v: -37.1,	Rn: -38.1,	loss: 3.36,	training_step: 3.65e+04
# INFO:TrainMonitor:ep: 131,	T: 36,975,	G: 17,	avg_r: 0.0729,	avg_G: 11.4,	t: 233,	dt: 46.912ms,	v: -48.9,	Rn: -43.9,	loss: 3.35,	training_step: 3.67e+04,	test_G: 39.3
# INFO:TrainMonitor:ep: 132,	T: 37,098,	G: 18.1,	avg_r: 0.149,	avg_G: 12,	t: 122,	dt: 50.223ms,	v: -31.1,	Rn: -21.5,	loss: 3.37,	training_step: 3.68e+04
# INFO:TrainMonitor:ep: 133,	T: 37,225,	G: -14.6,	avg_r: -0.116,	avg_G: 9.36,	t: 126,	dt: 35.334ms,	v: -27.9,	Rn: -33.4,	loss: 3.34,	training_step: 3.7e+04
# INFO:TrainMonitor:ep: 134,	T: 37,357,	G: -11.2,	avg_r: -0.0857,	avg_G: 7.3,	t: 131,	dt: 37.172ms,	v: -27.6,	Rn: -31.2,	loss: 3.37,	training_step: 3.71e+04
# INFO:TrainMonitor:ep: 135,	T: 37,575,	G: 45.5,	avg_r: 0.21,	avg_G: 11.1,	t: 217,	dt: 35.782ms,	v: -45.6,	Rn: -33.8,	loss: 3.36,	training_step: 3.73e+04
# INFO:TrainMonitor:ep: 136,	T: 37,777,	G: 21.9,	avg_r: 0.109,	avg_G: 12.2,	t: 201,	dt: 36.700ms,	v: -43.9,	Rn: -37.7,	loss: 3.37,	training_step: 3.75e+04
# INFO:TrainMonitor:ep: 137,	T: 38,015,	G: -12.4,	avg_r: -0.0522,	avg_G: 9.74,	t: 237,	dt: 35.929ms,	v: -49.9,	Rn: -42.5,	loss: 3.35,	training_step: 3.77e+04
# INFO:TrainMonitor:ep: 138,	T: 38,208,	G: 46.4,	avg_r: 0.242,	avg_G: 13.4,	t: 192,	dt: 36.123ms,	v: -37.1,	Rn: -23.5,	loss: 3.36,	training_step: 3.79e+04
# INFO:TrainMonitor:ep: 139,	T: 38,432,	G: 16.5,	avg_r: 0.0742,	avg_G: 13.7,	t: 223,	dt: 35.383ms,	v: -41.2,	Rn: -37,	loss: 3.35,	training_step: 3.82e+04
# INFO:TrainMonitor:ep: 140,	T: 39,433,	G: 143,	avg_r: 0.143,	avg_G: 26.6,	t: 1000,	dt: 40.586ms,	v: -12.4,	Rn: 43.6,	loss: 3.37,	training_step: 3.92e+04
# INFO:TrainMonitor:ep: 141,	T: 39,567,	G: 26.6,	avg_r: 0.2,	avg_G: 26.6,	t: 133,	dt: 50.290ms,	v: -27.9,	Rn: -17.5,	loss: 3.38,	training_step: 3.93e+04,	test_G: -26.1
# INFO:TrainMonitor:ep: 142,	T: 39,794,	G: -4.7,	avg_r: -0.0208,	avg_G: 23.5,	t: 226,	dt: 37.124ms,	v: -48.4,	Rn: -46.1,	loss: 3.37,	training_step: 3.95e+04
# INFO:TrainMonitor:ep: 143,	T: 39,928,	G: 47.6,	avg_r: 0.358,	avg_G: 25.9,	t: 133,	dt: 34.386ms,	v: -28.8,	Rn: -12.6,	loss: 3.37,	training_step: 3.96e+04
# INFO:TrainMonitor:ep: 144,	T: 40,110,	G: 30.1,	avg_r: 0.167,	avg_G: 26.3,	t: 181,	dt: 40.141ms,	v: -39.8,	Rn: -30.5,	loss: 3.38,	training_step: 3.98e+04

# %%
model_path
# Out:
# '/home/fangbowen/models/LunarLander/epoch_0070_test_G_65.80075034/lunarlander_model_params'

# %%
model = muax.MuZero(repr_fn, pred_fn, dy_fn, policy='muzero', discount=discount,
                    optimizer=gradient_transform, support_size=support_size)

model.load(model_path)

# %%
import gymnasium as gym 
from muax.test import test
env_id = 'LunarLander-v2'
test_env = gym.make(env_id, render_mode='rgb_array')
test_key = jax.random.PRNGKey(0)
test(model, test_env, test_key, num_simulations=50, num_test_episodes=100, random_seed=None)
# Out:
# 71.58757116828816
